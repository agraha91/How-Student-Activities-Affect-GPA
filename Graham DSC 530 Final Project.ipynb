# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import lognorm
import statsmodels.formula.api as smf

df = pd.read_csv('student_lifestyle_dataset.csv')

import thinkstats2
import thinkplot

# %%
StudentData = df

print(StudentData)
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0             14                  5.0                            3.3
# 1             25                  5.0                            2.0
# 2             40                  5.0                            0.6
# 3            359                  5.0                            1.0
# 4            483                  5.0                            4.0
# ...          ...                  ...                            ...
# 1995        1106                 10.0                            0.8
# 1996        1287                 10.0                            1.6
# 1997        1289                 10.0                            1.1
# 1998        1469                 10.0                            3.0
# 1999        1612                 10.0                            1.0
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.5                   4.4
# ...

# %%
# Cleaning the Dataset
def ReadStudentData(csv_file='student_lifestyle_dataset.csv',
                nrows=None):
    csv = thinkstats2.ReadStataDct(csv_file)
    df = dct.ReadFixedWidth(csv_file, compression='gzip', nrows=nrows)
    CleanStudentData(df)
    return df

# %%
def CleanStudentData(df):
    pass

# %%
# Variable Histograms

# %%
Study_Hours = df['Study_Hours_Per_Day']
ExtraC_Hours = df['Extracurricular_Hours_Per_Day']
Sleep_Hours = df['Sleep_Hours_Per_Day']
Social_Hours = df['Social_Hours_Per_Day']
Physical_Hours = df['Physical_Activity_Hours_Per_Day']
GPAT = df['GPA']

# %%
# Study Hours Per Day

hist = thinkstats2.Hist(Study_Hours, label='Study Hours Per Day')
thinkplot.Hist(hist)
thinkplot.Show(xlabel='Study Hours Per Day', ylabel='frequency')

# %%
# Extracurricular Hours Per Day

hist = thinkstats2.Hist(ExtraC_Hours, label='Extracurricular Hours Per Day')
thinkplot.Hist(hist,color='green')
thinkplot.Show(xlabel='Extracurricular Hours Per Day', ylabel='frequency')

# %%
# Sleep Hours Per Day

hist = thinkstats2.Hist(Sleep_Hours, label='Sleep Hours Per Day')
thinkplot.Hist(hist,color='purple')
thinkplot.Show(xlabel='Sleep Hours Per Day', ylabel='frequency')

# %%
#Social Hours Per Day

hist = thinkstats2.Hist(Social_Hours, label='Social Hours Per Day')
thinkplot.Hist(hist,color='orange')
thinkplot.Show(xlabel='Social Hours Per Day', ylabel='frequency')

# %%
# Physical Hours Per Day

hist = thinkstats2.Hist(Physical_Hours, label='Physical Hours Per Day')
thinkplot.Hist(hist,color='red')
thinkplot.Show(xlabel='Physical Hours Per Day', ylabel='frequency')

# %%
# GPA

hist = thinkstats2.Hist(GPAT, label='GPA')
thinkplot.Hist(hist,color='black')
thinkplot.Show(xlabel='GPAT', ylabel='frequency')

# %%
# Stress Level

hist = thinkstats2.Hist(Stress_Level, label='Stress Level')
thinkplot.Hist(hist,color='grey')
thinkplot.Show(xlabel='Stress Level', ylabel='frequency')

# %%
# Other Desciptive Characteristics

# %%
# Study

Study_Mean = Study_Hours.mean()
Study_Mode = Study_Hours.mode()
Study_Var = Study_Hours.var()
Study_SD = Study_Hours.std()
Study_Tails = Study_Hours.tail

print('Mean', Study_Mean)
print('Mode', Study_Mode)
print('Variance', Study_Var)
print('Standard Deviation', Study_SD)
print('Tails', Study_Tails)
# Out:
# Mean 7.4758
# Mode 0    6.3
# Name: Study_Hours_Per_Day, dtype: float64
# Variance 2.027458089044523
# Standard Deviation 1.4238883695867885
# Tails <bound method NDFrame.tail of 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
#         ...
# 1995    10.0
# 1996    10.0
# 1997    10.0
# 1998    10.0
# 1999    10.0
# Name: Study_Hours_Per_Day, Length: 2000, dtype: float64>

# %%
# Extracurricular

ExtraC_Mean = ExtraC_Hours.mean()
ExtraC_Mode = ExtraC_Hours.mode()
ExtraC_Var = ExtraC_Hours.var()
ExtraC_SD = ExtraC_Hours.std()
ExtraC_Tails = ExtraC_Hours.tail

print('Mean', ExtraC_Mean)
print('Mode', ExtraC_Mode)
print('Variance', ExtraC_Var)
print('Standard Deviation', ExtraC_SD)
print('Tails', ExtraC_Tails)
# Out:
# Mean 1.9901
# Mode 0    1.6
# Name: Extracurricular_Hours_Per_Day, dtype: float64
# Variance 1.3359999899949875
# Standard Deviation 1.1558546578160194
# Tails <bound method NDFrame.tail of 0       3.3
# 1       2.0
# 2       0.6
# 3       1.0
# 4       4.0
#        ...
# 1995    0.8
# 1996    1.6
# 1997    1.1
# 1998    3.0
# 1999    1.0
# Name: Extracurricular_Hours_Per_Day, Length: 2000, dtype: float64>

# %%
# Sleep

Sleep_Mean = Sleep_Hours.mean()
Sleep_Mode = Sleep_Hours.mode()
Sleep_Var = Sleep_Hours.var()
Sleep_SD = Sleep_Hours.std()
Sleep_Tails = Sleep_Hours.tail

print('Mean', Sleep_Mean)
print('Mode', Sleep_Mode)
print('Variance', Sleep_Var)
print('Standard Deviation', Sleep_SD)
print('Tails', Sleep_Tails)
# Out:
# Mean 7.50125
# Mode 0    5.4
# Name: Sleep_Hours_Per_Day, dtype: float64
# Variance 2.1343706228113972
# Standard Deviation 1.460948535305538
# Tails <bound method NDFrame.tail of 0       8.5
# 1       7.1
# 2       7.7
# 3       8.6
# 4       8.4
#        ...
# 1995    6.3
# 1996    6.4
# 1997    6.4
# 1998    8.2
# 1999    7.2
# Name: Sleep_Hours_Per_Day, Length: 2000, dtype: float64>

# %%
# Social

Social_Mean = Social_Hours.mean()
Social_Mode = Social_Hours.mode()
Social_Var = Social_Hours.var()
Social_SD = Social_Hours.std()
Social_Tails = Social_Hours.tail

print('Mean', Social_Mean)
print('Mode', Social_Mode)
print('Variance', Social_Var)
print('Standard Deviation', Social_SD)
print('Tails', Social_Tails)
# Out:
# Mean 2.7045500000000002
# Mode 0    0.3
# Name: Social_Hours_Per_Day, dtype: float64
# Variance 2.8510798374187014
# Standard Deviation 1.6885140915665173
# Tails <bound method NDFrame.tail of 0       4.4
# 1       1.3
# 2       4.2
# 3       6.0
# 4       5.0
#        ...
# 1995    4.0
# 1996    3.3
# 1997    1.0
# 1998    1.0
# 1999    3.0
# Name: Social_Hours_Per_Day, Length: 2000, dtype: float64>

# %%
# Physical 

Physical_Mean = Physical_Hours.mean()
Physical_Mode = Physical_Hours.mode()
Physical_Var = Physical_Hours.var()
Physical_SD = Physical_Hours.std()
Physical_Tails = Physical_Hours.tail

print('Mean', Physical_Mean)
print('Mode', Physical_Mode)
print('Variance', Physical_Var)
print('Standard Deviation', Physical_SD)
print('Tails', Physical_Tails)
# Out:
# Mean 4.3283000000000005
# Mode 0    4.3
# Name: Physical_Activity_Hours_Per_Day, dtype: float64
# Variance 6.320749484742432
# Standard Deviation 2.514110078087758
# Tails <bound method NDFrame.tail of 0       2.8
# 1       8.6
# 2       6.5
# 3       3.4
# 4       1.6
#        ...
# 1995    2.9
# 1996    2.7
# 1997    5.5
# 1998    1.8
# 1999    2.8
# Name: Physical_Activity_Hours_Per_Day, Length: 2000, dtype: float64>

# %%
# GPA

GPA_Mean = GPAT.mean()
GPA_Mode = GPAT.mode()
GPA_Var = GPAT.var()
GPA_SD = GPAT.std()
GPA_Tails = GPAT.tail

print('Mean', GPA_Mean)
print('Mode', GPA_Mode)
print('Variance', GPA_Var)
print('Standard Deviation', GPA_SD)
print('Tails', GPA_Tails)
# Out:
# Mean 3.11596
# Mode 0    3.11
# Name: GPA, dtype: float64
# Variance 0.08920588134067027
# Standard Deviation 0.2986735363916098
# Tails <bound method NDFrame.tail of 0       2.87
# 1       2.68
# 2       2.61
# 3       2.71
# 4       2.90
#         ...
# 1995    3.39
# 1996    3.39
# 1997    3.40
# 1998    3.81
# 1999    3.37
# Name: GPA, Length: 2000, dtype: float64>

# %%
# PMF of GPA for hours of sleep per day

# %%
high = StudentData.GPA >= 3.00
low = StudentData.GPA < 3.00

# %%
ReadStudentData

GPA0 = df[StudentData['GPA']>= 0.00]
high = df[StudentData['GPA'] >= 3.00]
low = df[StudentData['GPA'] < 3.00]

# %%
high_sleep = high.Sleep_Hours_Per_Day
high_sleep_dropna = high_sleep.dropna()
print('High GPA', len(high_sleep), len(high_sleep_dropna))
 
low_sleep = low.Sleep_Hours_Per_Day
low_sleep_dropna = low_sleep.dropna()
print('Low GPA', len(low_sleep), len(low_sleep_dropna))

high_pmf = thinkstats2.Pmf(high_sleep_dropna, label='High GPA')
low_pmf = thinkstats2.Pmf(low_sleep_dropna, label='Low GPA')
# Out:
# High GPA 1288 1288
# Low GPA 712 712

# %%
width = 0.45

thinkplot.PrePlot(2)
thinkplot.Hist(high_pmf, align='right', width=width, color='green')
thinkplot.Hist(low_pmf, align='left', width=width, color='purple')
thinkplot.Config(xlabel='Hours of Sleep', ylabel='PMF')

# %%
# CDF

# %%
mu = Sleep_Mean
sigma = Sleep_SD
dist = stats.norm(loc=mu, scale=sigma)
type(dist)
# Out:
# scipy.stats._distn_infrastructure.rv_continuous_frozen

# %%
# How many people are below the mean by one standard deviation
dist.cdf(mu - sigma)
# Out:
# 0.15865525393145707

# %%
high_cdf = thinkstats2.Cdf(high.Study_Hours_Per_Day, label='High GPA')
low_cdf = thinkstats2.Cdf(low.Study_Hours_Per_Day, label='Low GPA')

thinkplot.PrePlot(2)
thinkplot.Cdfs([high_cdf, low_cdf])
thinkplot.Config(xlabel='Hours of Studying', ylabel='CDF')

# %%
cdf = thinkstats2.Cdf(StudentData.Study_Hours_Per_Day, label='Hours Studying')


thinkplot.PrePlot(2)
thinkplot.Cdfs([cdf])
thinkplot.Config(xlabel='Hours of Studying', ylabel='CDF')

# %%
# The Lognormal Distribution of Social Hours

# %%
social = df.Social_Hours_Per_Day.dropna()

# %%
def MakeNormalModel(social):
    cdf = thinkstats2.Cdf(social, label="Social (Hours Per Day")

    mean, var = thinkstats2.TrimmedMeanVar(social)
    std = np.sqrt(var)
    print("n, mean, std", len(social), mean, std)

    xmin = mean - 4 * std
    xmax = mean + 4 * std

    xs, ps = thinkstats2.RenderNormalCdf(mean, std, xmin, xmax)
    thinkplot.Plot(xs, ps, label="model", linewidth=4, color="0.8")
    thinkplot.Cdf(cdf)

# %%
MakeNormalModel(social)
thinkplot.Config(
    title="Social Time, linear scale",
    xlabel="Social Time",
    ylabel="CDF",
    loc="upper right",
)
# Out:
# n, mean, std 2000 2.6986224489795925 1.6505110959528257

# %%
log_social = np.log10(social)
MakeNormalModel(log_social)
thinkplot.Config(
    title="Social Time, log scale",
    xlabel="Social Time (Hours Per Day",
    ylabel="CDF",
    loc="upper right",
)
# Out:
# n, mean, std 2000 0.29897429514465773 0.40421193545904954
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Scatterplots

# %%
# Physical Activity vs Study Time
thinkplot.Scatter(Physical_Hours, Study_Hours, alpha=0.05, s=10)
thinkplot.Config(xlabel='Physical Activity (Hour per Day)',
                     ylabel='Study Time (Hours per Day)',
                     xlim=[0, 13],
                     ylim=[0, 12],
                     legend=False)

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

# %%
def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

# %%
def SpearmanCorr(xs, ys):
    xranks = pd.Series(xs).rank()
    yranks = pd.Series(ys).rank()
    return Corr(xranks, yranks)

# %%
print('Covariance', Cov(Physical_Hours, Study_Hours))
print('Pearsons Correlation', Corr(Physical_Hours, Study_Hours))
# Out:
# Covariance -1.7464801399999985
# Pearsons Correlation -0.48811327747733196

# %%
# Sleep Hours vs Study Hours

# %%
thinkplot.Scatter(Sleep_Hours, Study_Hours, alpha=0.05, s=12)
thinkplot.Config(xlabel='Sleep (Hour per Day)',
                     ylabel='Study Time (Hours per Day)',
                     xlim=[0, 13],
                     ylim=[0, 12],
                     legend=False)

# %%
print('Covariance', Cov(Sleep_Hours, Study_Hours))
print('Pearsons Correlation', Corr(Sleep_Hours, Study_Hours))
# Out:
# Covariance 0.05555025000000004
# Pearsons Correlation 0.026717287219816158

# %%
#Hypothesis Test

# %%
highGPA = length1 = len(high)
lowGPA = length2 = len(low)

print(length1)
print(length2)
# Out:
# 1288
# 712

# %%
class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel()) 
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class StudentGPATest(HypothesisTest):

    def TestStatistic(self, data):
        high, low = data
        test_stat = abs(high - low)
        return test_stat

    def RunModel(self):
        high, low = self.data
        n = high + low
        sample = [random.choice('HT') for _ in range(n)]
        hist = thinkstats2.Hist(sample)
        data = hist['H'], hist['T']
        return data

# %%
gt = StudentGPATest((highGPA, lowGPA ))
pvalue = gt.PValue()
pvalue
# Out:
# 0.0

# %%
def MakeFrames():
    """Reads pregnancy data and partitions first babies and others.

    returns: DataFrames (all live births, first babies, others)
    """

    GPA0 = df[StudentData['GPA']> 0]
    high = df[StudentData['GPA'] >= 3.00]
    low = df[StudentData['GPA'] < 3.00]

    assert len(GPA0) == 2000
    assert len(high) == 1288
    assert len(low) == 712

    return GPA0, high, low

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
GPA0, high, low = MakeFrames()
data = high.Study_Hours_Per_Day.values, low.Study_Hours_Per_Day.values
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
ht.PlotCdf()
thinkplot.Show(xlabel='test statistic', ylabel='CDF')

# %%
#Regression Analysis

# %%
diff_study = high.Study_Hours_Per_Day.mean()-low.Study_Hours_Per_Day.mean()
diff_study
# Out:
# 1.8449682462139725

# %%
diff_physical = high.Physical_Activity_Hours_Per_Day.mean()-low.Physical_Activity_Hours_Per_Day.mean()
diff_physical
# Out:
# -1.3258741014725377

# %%
results = smf.ols('Study_Hours_Per_Day ~ Physical_Activity_Hours_Per_Day', data = GPA).fit()
slope = results.params['Physical_Activity_Hours_Per_Day']

# %%
GPA['ishigh'] = GPA.GPA >= 3.00
formula = 'Study_Hours_Per_Day ~ ishigh'
results = smf.ols(formula, data = GPA).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Study_Hours_Per_Day   R-squared:                       0.385
# Model:                             OLS   Adj. R-squared:                  0.385
# Method:                  Least Squares   F-statistic:                     1251.
# Date:                 Sun, 17 Nov 2024   Prob (F-statistic):          2.96e-213
# Time:                         23:46:41   Log-Likelihood:                -3057.9
# No. Observations:                 2000   AIC:                             6120.
# Df Residuals:                     1998   BIC:                             6131.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
GPA['ishigh'] = GPA.GPA >= 3.00
formula = 'Physical_Activity_Hours_Per_Day ~ ishigh'
results = smf.ols(formula, data = GPA).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     Physical_Activity_Hours_Per_Day   R-squared:                       0.064
# Model:                                         OLS   Adj. R-squared:                  0.063
# Method:                              Least Squares   F-statistic:                     136.1
# Date:                             Sun, 17 Nov 2024   Prob (F-statistic):           1.76e-30
# Time:                                     23:46:41   Log-Likelihood:                -4615.3
# No. Observations:                             2000   AIC:                             9235.
# Df Residuals:                                 1998   BIC:                             9246.
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
formula = 'Study_Hours_Per_Day ~ ishigh + Physical_Activity_Hours_Per_Day'
results = smf.ols(formula, data=GPA).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Study_Hours_Per_Day   R-squared:                       0.502
# Model:                             OLS   Adj. R-squared:                  0.502
# Method:                  Least Squares   F-statistic:                     1008.
# Date:                 Sun, 17 Nov 2024   Prob (F-statistic):          2.19e-303
# Time:                         23:46:41   Log-Likelihood:                -2846.2
# No. Observations:                 2000   AIC:                             5698.
# Df Residuals:                     1997   BIC:                             5715.
# Df Model:                            2
# Covariance Type:             nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...
